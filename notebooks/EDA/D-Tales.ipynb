# %%
import pandas as pd
import dtale
from dtale import show

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from dtale import show
#       2 import sys, subprocess
#       3 from dtale import show
#
# ModuleNotFoundError: No module named 'dtale'
